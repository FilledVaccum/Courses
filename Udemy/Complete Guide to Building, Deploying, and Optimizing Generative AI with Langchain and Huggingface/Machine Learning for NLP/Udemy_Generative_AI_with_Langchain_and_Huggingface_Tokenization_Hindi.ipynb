# %% [markdown]
# <a href="https://colab.research.google.com/github/FilledVaccum/Courses/blob/default-main/Udemy/Complete%20Guide%20to%20Building%2C%20Deploying%2C%20and%20Optimizing%20Generative%20AI%20with%20Langchain%20and%20Huggingface/Machine%20Learning%20for%20NLP/Udemy_Generative_AI_with_Langchain_and_Huggingface_Tokenization_Hindi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk

# %%
corpus =  """ आई हैव ए ड्रीम (अंग्रेज़ी: I Have a Dream, अर्थ: "मेरा एक सपना है") एक सार्वजनिक भाषण है जो अमेरिकी नागरिक अधिकार कार्यकर्ता और बैप्टिस्ट मंत्री मार्टिन लूथर किंग द्वारा 28 अगस्त, 1963 को दिया गया था।[2] भाषण में किंग ने नागरिक और आर्थिक अधिकारों की वकालत की और संयुक्त राज्य अमेरिका में नस्लवाद के अंत का आवाहन किया। वाशिंगटन डीसी में लिंकन मेमोरियल की सीढ़ियों से 2,50,000 से अधिक नागरिक अधिकार समर्थकों को दिया गया भाषण अफ्रीकी-अमेरिकी अधिकार आंदोलन के सबसे प्रसिद्ध क्षणों में से एक था और अमेरिकी इतिहास में सबसे प्रतिष्ठित भाषणों में से एक है।[3][4]

1863 में अब्राहम लिंकन द्वारा अमरीकी गृह युद्ध के बीच में गुलामों को स्वतंत्र करने के आदेश से शुरुआत करते हुए, किंग ने कहा "एक सौ साल बाद भी नीग्रो अभी भी स्वतंत्र नहीं है"। भाषण के अंत में किंग अपने पहले से तैयार भाषण से इतर चले जाते हैं और एक वक्तव्य बोलना शुरू करते हैं। इसी का विषय होता है, "मेरा एक सपना है"। भाषण के इसी भाग ने श्रोताओं को सबसे अधिक उत्साहित किया और अब यह सबसे प्रसिद्ध हो गया है। इसमें किंग ने दासता और घृणा की भूमि से उत्पन्न स्वतंत्रता और समानता के अपने सपनों का वर्णन किया।

जॉन मेचम लिखते हैं कि, "एक वाक्यांश के साथ, किंग ने अपने आप को जेफरसन और लिंकन के साथ आधुनिक अमेरिका को आकार देने वाले पुरुषों की श्रेणी में शामिल कर लिया।"[5] 1999 में सार्वजनिक उद्बोधन के विद्वानों के एक सर्वेक्षण में इस भाषण को 20वीं शताब्दी के शीर्ष अमेरिकी भाषण का दर्जा दिया गया था। """

# %%
print(corpus)
# Out:
#  आई हैव ए ड्रीम (अंग्रेज़ी: I Have a Dream, अर्थ: "मेरा एक सपना है") एक सार्वजनिक भाषण है जो अमेरिकी नागरिक अधिकार कार्यकर्ता और बैप्टिस्ट मंत्री मार्टिन लूथर किंग द्वारा 28 अगस्त, 1963 को दिया गया था।[2] भाषण में किंग ने नागरिक और आर्थिक अधिकारों की वकालत की और संयुक्त राज्य अमेरिका में नस्लवाद के अंत का आवाहन किया। वाशिंगटन डीसी में लिंकन मेमोरियल की सीढ़ियों से 2,50,000 से अधिक नागरिक अधिकार समर्थकों को दिया गया भाषण अफ्रीकी-अमेरिकी अधिकार आंदोलन के सबसे प्रसिद्ध क्षणों में से एक था और अमेरिकी इतिहास में सबसे प्रतिष्ठित भाषणों में से एक है।[3][4]
#
# ...

# %% [markdown]
#     Import nltk: This line imports the nltk library, making its functions available.
#     Download punkt_tab: This line uses nltk.download('punkt_tab') to download the necessary Punkt Tokenizer models. This will store the models in your NLTK data directory, so you only need to download them once.
#     Import sent_tokenize: Imports the function needed for tokenization.
#     Tokenize and Print: This line calls sent_tokenize(corpus) to tokenize the text stored in the corpus variable, and then it prints the resulting list of sentences.

# %%
## Tokenisation

## Paragraphs ---> Sentences

# Import Library
import nltk

# Download Punkt Tokenizer Model
nltk.download('punkt_tab')

# Import sent_tokenize function to tokenize the corpus
from nltk.tokenize import sent_tokenize
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
documents = sent_tokenize(corpus)

# %%
type(documents)
# Out:
# list

# %%
for sentence in documents:
  print(sentence)
# Out:
#  आई हैव ए ड्रीम (अंग्रेज़ी: I Have a Dream, अर्थ: "मेरा एक सपना है") एक सार्वजनिक भाषण है जो अमेरिकी नागरिक अधिकार कार्यकर्ता और बैप्टिस्ट मंत्री मार्टिन लूथर किंग द्वारा 28 अगस्त, 1963 को दिया गया था।[2] भाषण में किंग ने नागरिक और आर्थिक अधिकारों की वकालत की और संयुक्त राज्य अमेरिका में नस्लवाद के अंत का आवाहन किया। वाशिंगटन डीसी में लिंकन मेमोरियल की सीढ़ियों से 2,50,000 से अधिक नागरिक अधिकार समर्थकों को दिया गया भाषण अफ्रीकी-अमेरिकी अधिकार आंदोलन के सबसे प्रसिद्ध क्षणों में से एक था और अमेरिकी इतिहास में सबसे प्रतिष्ठित भाषणों में से एक है।[3][4]
#
# ...

# %% [markdown]
# # Tokenization Part 2
#
# ## Converting Paragraphs into Words
# ## Converting Documents into Words

# %%
from nltk.tokenize import word_tokenize

# %%
vocabulary = word_tokenize(corpus)

# %%
for word in vocabulary:
  print(word)
# Out:
# आई
# हैव
# ए
# ड्रीम
# (
# अंग्रेज़ी
# :
# I
# Have
# a
# Dream
# ,
# अर्थ
# :
# ``
# मेरा
# एक
# सपना
# है
# ''
# )
# एक
# सार्वजनिक
# भाषण
# है
# जो
# अमेरिकी
# नागरिक
# अधिकार
# कार्यकर्ता
# और
# बैप्टिस्ट
# मंत्री
# मार्टिन
# लूथर
# किंग
# द्वारा
# 28
# अगस्त
# ,
# 1963
# को
# दिया
# गया
# था।
# [
# 2
# ]
# भाषण
# में
# किंग
# ने
# नागरिक
# और
# आर्थिक
# अधिकारों
# की
# वकालत
# की
# और
# संयुक्त
# राज्य
# अमेरिका
# में
# नस्लवाद
# के
# अंत
# का
# आवाहन
# किया।
# वाशिंगटन
# डीसी
# में
# लिंकन
# मेमोरियल
# की
# सीढ़ियों
# से
# 2,50,000
# से
# अधिक
# नागरिक
# अधिकार
# समर्थकों
# को
# दिया
# गया
# भाषण
# अफ्रीकी-अमेरिकी
# अधिकार
# आंदोलन
# के
# सबसे
# प्रसिद्ध
# क्षणों
# में
# से
# एक
# था
# और
# अमेरिकी
# इतिहास
# में
# सबसे
# प्रतिष्ठित
# भाषणों
# में
# से
# एक
# है।
# [
# 3
# ]
# [
# 4
# ]
# 1863
# में
# अब्राहम
# लिंकन
# द्वारा
# अमरीकी
# गृह
# युद्ध
# के
# बीच
# में
# गुलामों
# को
# स्वतंत्र
# करने
# के
# आदेश
# से
# शुरुआत
# करते
# हुए
# ,
# किंग
# ने
# कहा
# ``
# एक
# सौ
# ...

# %%
# in this case the punctuation is considered as a different sentence

from nltk.tokenize import wordpunct_tokenize

# %%
# in this case the punctuation is considered as a different sentence

wordpunct_tokenize(corpus)
# Out:
# ['आई',
#  'ह',
#  'ै',
#  'व',
#  'ए',
#  'ड',
#  '्',
#  'र',
#  'ी',
#  'म',
#  '(',
#  'अ',
#  'ं',
#  'ग',
#  '्',
#  'र',
#  'े',
#  'ज',
#  '़ी:',
#  'I',
#  'Have',
#  'a',
#  'Dream',
#  ',',
#  'अर',
#  '्',
#  'थ',
#  ':',
#  '"',
#  'म',
#  'े',
#  'र',
#  'ा',
#  'एक',
#  'सपन',
#  'ा',
#  'ह',
#  'ै")',
#  'एक',
#  'स',
#  'ा',
#  'र',
#  '्',
#  'वजन',
#  'ि',
#  'क',
#  'भ',
#  'ा',
#  'षण',
#  'ह',
#  'ै',
#  'ज',
#  'ो',
#  'अम',
#  'े',
#  'र',
#  'ि',
#  'क',
#  'ी',
#  'न',
#  'ा',
#  'गर',
#  'ि',
#  'क',
#  'अध',
#  'ि',
#  'क',
#  'ा',
#  'र',
#  'क',
#  'ा',
#  'र',
#  '्',
#  'यकर',
#  '्',
#  'त',
#  'ा',
#  'और',
#  'ब',
#  'ै',
#  'प',
#  '्',
#  'ट',
#  'ि',
#  'स',
#  '्',
#  'ट',
#  'म',
#  'ं',
#  'त',
#  '्',
#  'र',
#  'ी',
#  'म',
#  'ा',
#  'र',
#  '्',
#  'ट',
#  'ि',
#  'न',
#  'ल',
#  'ू',
#  'थर',
#  'क',
#  'िं',
#  'ग',
#  'द',
#  '्',
#  'व',
#  'ा',
#  'र',
#  'ा',
#  '28',
#  'अगस',
#  '्',
#  'त',
#  ',',
#  '1963',
#  'क',
#  'ो',
# ...

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer = TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['आई',
#  'हैव',
#  'ए',
#  'ड्रीम',
#  '(',
#  'अंग्रेज़ी',
#  ':',
#  'I',
#  'Have',
#  'a',
#  'Dream',
#  ',',
#  'अर्थ',
#  ':',
#  '``',
#  'मेरा',
#  'एक',
#  'सपना',
#  'है',
#  "''",
#  ')',
#  'एक',
#  'सार्वजनिक',
#  'भाषण',
#  'है',
#  'जो',
#  'अमेरिकी',
#  'नागरिक',
#  'अधिकार',
#  'कार्यकर्ता',
#  'और',
#  'बैप्टिस्ट',
#  'मंत्री',
#  'मार्टिन',
#  'लूथर',
#  'किंग',
#  'द्वारा',
#  '28',
#  'अगस्त',
#  ',',
#  '1963',
#  'को',
#  'दिया',
#  'गया',
#  'था।',
#  '[',
#  '2',
#  ']',
#  'भाषण',
#  'में',
#  'किंग',
#  'ने',
#  'नागरिक',
#  'और',
#  'आर्थिक',
#  'अधिकारों',
#  'की',
#  'वकालत',
#  'की',
#  'और',
#  'संयुक्त',
#  'राज्य',
#  'अमेरिका',
#  'में',
#  'नस्लवाद',
#  'के',
#  'अंत',
#  'का',
#  'आवाहन',
#  'किया।',
#  'वाशिंगटन',
#  'डीसी',
#  'में',
#  'लिंकन',
#  'मेमोरियल',
#  'की',
#  'सीढ़ियों',
#  'से',
#  '2,50,000',
#  'से',
#  'अधिक',
#  'नागरिक',
#  'अधिकार',
#  'समर्थकों',
#  'को',
#  'दिया',
#  'गया',
#  'भाषण',
#  'अफ्रीकी-अमेरिकी',
#  'अधिकार',
# ...
