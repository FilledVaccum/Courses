# %% [markdown]
# <a href="https://colab.research.google.com/github/FilledVaccum/Courses/blob/default-main/Machine%20Learning%20Specialization/Supervised%20Machine%20Learning%3A%20Regression%20and%20Classification/Week%202/Difference%20between%20calculation%20without%20vectorization%20and%20with%20vectorization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import time

# %%
# Creating two vector with random elements

import random

# Create an empty list to store the random elements
random_vector = []
random_vector2 = []
random_vector3 = []
random_vector4 = []

# Generate 10000 random numbers and append them to the list
for _ in range(1000000):
    random_vector.append(random.random())
    random_vector2.append(random.random())
    random_vector3.append(random.random())
    random_vector4.append(random.random())

# Print the list (optional)

# %%
start_time = time.time()

sum = 0
for i in range(1000000):
  random_vector3[i] = random_vector[i] * random_vector2[i]
  sum = sum + random_vector3[i]

print(sum)

end_time = time.time()

print(end_time - start_time)
# Out:
# 250404.0211100222
# 0.30666518211364746

# %%
start_time = time.time()

random_vector4 = np.dot(random_vector, random_vector2)

print(random_vector4)

end_time = time.time()

print(end_time - start_time)
# Out:
# 250404.02111001656
# 0.27684521675109863
